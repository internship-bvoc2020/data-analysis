# %% [markdown]
# <a href="https://colab.research.google.com/github/internship-bvoc2020/data-analysis/blob/master/DataAnalysis_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing** **Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Reading Cars datafile & performing basic checks on data file**

# %%
df_csv = pd.read_csv("cars.csv",sep=";")

# %%
df_csv.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
df_csv.head()
# Out:
#                          Car   MPG  Cylinders  ...  Acceleration  Model  Origin
# 0  Chevrolet Chevelle Malibu  18.0          8  ...          12.0     70      US
# 1          Buick Skylark 320  15.0          8  ...          11.5     70      US
# 2         Plymouth Satellite  18.0          8  ...          11.0     70      US
# 3              AMC Rebel SST  16.0          8  ...          12.0     70      US
# 4                Ford Torino  17.0          8  ...          10.5     70      US
#
# [5 rows x 9 columns]

# %% [markdown]
# **Cars data file basic sanity check using Data frame Operations & Features**

# %%
print('Number of records in dataframe is given by len(df_csv) function :'+str(len(df_csv)))
print('Dataframe records and columns count shaoe function :'+str(df_csv.shape))
print('Dataframe total objects count using size function :'+str(df_csv.size))
print('Dataframe each index and column individual counts are given by df_csv.count(axis=0or1)\n'+str(df_csv.count(axis=0)))
# Out:
# Number of records in dataframe is given by len(df_csv) function :406
# Dataframe records and columns count shaoe function :(406, 9)
# Dataframe total objects count using size function :3654
# Dataframe each index and column individual counts are given by df_csv.count(axis=0or1)
# Car             406
# MPG             406
# Cylinders       406
# Displacement    406
# Horsepower      406
# Weight          406
# Acceleration    406
# Model           406
# Origin          406
# dtype: int64

# %% [markdown]
# **Acessing Dataframe objects**

# %%
print('\n Tail function gives last few records in a dataframe df_csv.tail()\n :'+str(df_csv.tail()))
print('\nAccessing rows of a particular column of Dataframe using indexer for ex df_csv.ix[3:10,\'Car\']\n'+str(df_csv.loc[3:10,'Car']))
# Out:
#  Tail function gives last few records in a dataframe df_csv.tail()
#  :                   Car   MPG  Cylinders  ...  Acceleration  Model  Origin
# 401    Ford Mustang GL  27.0          4  ...          15.6     82      US
# 402  Volkswagen Pickup  44.0          4  ...          24.6     82  Europe
# 403      Dodge Rampage  32.0          4  ...          11.6     82      US
# 404        Ford Ranger  28.0          4  ...          18.6     82      US
# 405         Chevy S-10  31.0          4  ...          19.4     82      US
#
# [5 rows x 9 columns]
#
# Accessing rows of a particular column of Dataframe using indexer for ex df_csv.ix[3:10,'Car']
# 3            AMC Rebel SST
# 4              Ford Torino
# 5         Ford Galaxie 500
# 6         Chevrolet Impala
# 7        Plymouth Fury iii
# 8         Pontiac Catalina
# 9       AMC Ambassador DPL
# 10    Citroen DS-21 Pallas
# Name: Car, dtype: object

# %% [markdown]
# **Transposing a Dataframe i.e. Row becomes columns and columns becomes** **rows**

# %%
df_csv.T
# Out:
#                                       0  ...         405
# Car           Chevrolet Chevelle Malibu  ...  Chevy S-10
# MPG                                  18  ...          31
# Cylinders                             8  ...           4
# Displacement                        307  ...         119
# Horsepower                          130  ...          82
# Weight                             3504  ...        2720
# Acceleration                         12  ...        19.4
# Model                                70  ...          82
# Origin                               US  ...          US
#
# [9 rows x 406 columns]

# %%
df_csv.T.shape
# Out:
# (9, 406)

# %% [markdown]
# **Adding New column in dataframe**

# %%
df_csv['NetHPWt'] = df_csv['Horsepower'] + df_csv['Weight']
df_csv.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin', 'NetHPWt'],
#       dtype='object')

# %% [markdown]
# **Pivoting in Dataframe**

# %%
df_csv[['Car','Acceleration','Origin']].head()
# Out:
#                          Car  Acceleration Origin
# 0  Chevrolet Chevelle Malibu          12.0     US
# 1          Buick Skylark 320          11.5     US
# 2         Plymouth Satellite          11.0     US
# 3              AMC Rebel SST          12.0     US
# 4                Ford Torino          10.5     US

# %%
df_table=pd.pivot_table(df_csv, values='Acceleration', index=['Car'],columns=['Origin'])
df_table
# Out:
# Origin                                   Europe  Japan         US
# Car
# AMC Ambassador Brougham                     NaN    NaN  11.000000
# AMC Ambassador DPL                          NaN    NaN   8.500000
# AMC Ambassador SST                          NaN    NaN  11.500000
# AMC Concord                                 NaN    NaN  18.650000
# AMC Concord DL                              NaN    NaN  20.500000
# AMC Concord DL 6                            NaN    NaN  18.200000
# AMC Concord d/l                             NaN    NaN  15.100000
# AMC Gremlin                                 NaN    NaN  14.750000
# AMC Hornet                                  NaN    NaN  16.275000
# AMC Hornet Sportabout (sw)                  NaN    NaN  13.500000
# AMC Matador                                 NaN    NaN  15.580000
# AMC Matador (sw)                            NaN    NaN  14.000000
# AMC Pacer                                   NaN    NaN  17.000000
# AMC Pacer d/l                               NaN    NaN  17.800000
# AMC Rebel SST                               NaN    NaN  12.000000
# AMC Rebel SST (sw)                          NaN    NaN  11.000000
# AMC Spirit DL                               NaN    NaN  15.000000
# Audi 100 LS                           14.500000    NaN        NaN
# Audi 100LS                            14.500000    NaN        NaN
# Audi 4000                             15.800000    NaN        NaN
# Audi 5000                             15.900000    NaN        NaN
# Audi 5000s (diesel)                   19.900000    NaN        NaN
# Audi Fox                              16.500000    NaN        NaN
# BMW 2002                              12.500000    NaN        NaN
# BMW 320i                              12.800000    NaN        NaN
# Buick Century                               NaN    NaN  18.400000
# Buick Century 350                           NaN    NaN  13.000000
# Buick Century Limited                       NaN    NaN  16.400000
# Buick Century Luxus (sw)                    NaN    NaN  14.500000
# Buick Century Special                       NaN    NaN  15.800000
# Buick Electra 225 Custom                    NaN    NaN  11.000000
# Buick Estate Wagon (sw)                     NaN    NaN  12.450000
# Buick LeSabre Custom                        NaN    NaN  13.500000
# Buick Opel Isuzu Deluxe                     NaN    NaN  14.800000
# Buick Regal Sport Coupe (turbo)             NaN    NaN  13.400000
# Buick Skyhawk                               NaN    NaN  15.000000
# Buick Skylark                               NaN    NaN  16.650000
# Buick Skylark 320                           NaN    NaN  11.500000
# Buick Skylark Limited                       NaN    NaN  16.000000
# Cadillac Eldorado                           NaN    NaN  17.400000
# Cadillac Seville                            NaN    NaN  12.100000
# Capri ii                                    NaN    NaN  14.900000
# Chevrolet Bel Air                           NaN    NaN  14.000000
# Chevrolet C10                               NaN    NaN  12.000000
# Chevrolet Camaro                            NaN    NaN  17.300000
# Chevrolet Caprice Classic                   NaN    NaN  13.300000
# Chevrolet Cavalier                          NaN    NaN  19.600000
# Chevrolet Cavalier 2-door                   NaN    NaN  18.000000
# Chevrolet Cavalier Wagon                    NaN    NaN  18.600000
# Chevrolet Chevelle Concours (sw)            NaN    NaN  12.750000
# Chevrolet Chevelle Malibu                   NaN    NaN  13.750000
# Chevrolet Chevelle Malibu Classic           NaN    NaN  15.000000
# Chevrolet Chevette                          NaN    NaN  17.800000
# Chevrolet Citation                          NaN    NaN  13.466667
# Chevrolet Concours                          NaN    NaN  16.400000
# Chevrolet Impala                            NaN    NaN  11.750000
# Chevrolet Malibu                            NaN    NaN  15.600000
# Chevrolet Malibu Classic (sw)               NaN    NaN  15.000000
# Chevrolet Monte Carlo                       NaN    NaN   9.500000
# Chevrolet Monte Carlo Landau                NaN    NaN  12.300000
# Chevrolet Monte Carlo S                     NaN    NaN  13.000000
# Chevrolet Monza 2+2                         NaN    NaN  13.500000
# Chevrolet Nova                              NaN    NaN  15.833333
# Chevrolet Nova Custom                       NaN    NaN  18.000000
# Chevrolet Vega                              NaN    NaN  18.666667
# Chevrolet Vega (sw)                         NaN    NaN  19.000000
# Chevrolet Vega 2300                         NaN    NaN  15.500000
# Chevrolet Woody                             NaN    NaN  22.100000
# Chevrolete Chevelle Malibu                  NaN    NaN  18.500000
# Chevy C20                                   NaN    NaN  15.000000
# Chevy S-10                                  NaN    NaN  19.400000
# Chrysler Cordoba                            NaN    NaN  12.200000
# Chrysler Lebaron Medallion                  NaN    NaN  14.500000
# Chrysler Lebaron Salon                      NaN    NaN  16.600000
# Chrysler Lebaron Town @ Country (sw)        NaN    NaN  13.000000
# Chrysler New Yorker Brougham                NaN    NaN  11.000000
# Chrysler Newport Royal                      NaN    NaN  12.500000
# Citroen DS-21 Pallas                  17.500000    NaN        NaN
# Datsun 1200                                 NaN  18.00        NaN
# Datsun 200-SX                               NaN  14.90        NaN
# Datsun 200SX                                NaN  14.80        NaN
# Datsun 210                                  NaN  19.20        NaN
# Datsun 210 MPG                              NaN  19.40        NaN
# Datsun 280-ZX                               NaN  11.40        NaN
# Datsun 310                                  NaN  16.40        NaN
# Datsun 310 GX                               NaN  16.20        NaN
# Datsun 510                                  NaN  14.70        NaN
# Datsun 510 (sw)                             NaN  17.00        NaN
# Datsun 510 Hatchback                        NaN  15.00        NaN
# Datsun 610                                  NaN  16.50        NaN
# Datsun 710                                  NaN  18.00        NaN
# Datsun 810                                  NaN  14.50        NaN
# Datsun 810 Maxima                           NaN  13.80        NaN
# Datsun B-210                                NaN  17.00        NaN
# Datsun B210                                 NaN  19.00        NaN
# Datsun B210 GX                              NaN  18.60        NaN
# Datsun F-10 Hatchback                       NaN  16.80        NaN
# Datsun PL510                                NaN  14.50        NaN
# Dodge Aries SE                              NaN    NaN  16.000000
# Dodge Aries Wagon (sw)                      NaN    NaN  14.400000
# Dodge Aspen                                 NaN    NaN  18.700000
# Dodge Aspen 6                               NaN    NaN  16.600000
# Dodge Aspen SE                              NaN    NaN  17.700000
# Dodge Challenger SE                         NaN    NaN  10.000000
# Dodge Charger 2.2                           NaN    NaN  13.000000
# Dodge Colt                                  NaN    NaN  15.533333
# Dodge Colt (sw)                             NaN    NaN  15.000000
# Dodge Colt Hardtop                          NaN    NaN  17.000000
# Dodge Colt Hatchback Custom                 NaN    NaN  14.400000
# Dodge Colt m/m                              NaN    NaN  15.900000
# Dodge Coronet Brougham                      NaN    NaN  13.000000
# Dodge Coronet Custom                        NaN    NaN  12.500000
# Dodge Coronet Custom (sw)                   NaN    NaN  13.500000
# Dodge D100                                  NaN    NaN  14.000000
# Dodge D200                                  NaN    NaN  13.500000
# Dodge Dart Custom                           NaN    NaN  11.000000
# Dodge Diplomat                              NaN    NaN  13.200000
# Dodge Magnum XE                             NaN    NaN  13.700000
# Dodge Monaco (sw)                           NaN    NaN  11.500000
# Dodge Monaco Brougham                       NaN    NaN  13.700000
# Dodge Omni                                  NaN    NaN  14.500000
# Dodge Rampage                               NaN    NaN  11.600000
# Dodge St. Regis                             NaN    NaN  15.200000
# Fiat 124 Sport Coupe                  15.500000    NaN        NaN
# Fiat 124 TC                           14.000000    NaN        NaN
# Fiat 124B                             14.500000    NaN        NaN
# Fiat 128                              17.500000    NaN        NaN
# Fiat 131                              15.500000    NaN        NaN
# Fiat Strada Custom                    14.700000    NaN        NaN
# Fiat x1.9                             16.000000    NaN        NaN
# Ford Country                                NaN    NaN  12.500000
# Ford Country Squire (sw)                    NaN    NaN  13.150000
# Ford Escort 2H                              NaN    NaN  20.700000
# Ford Escort 4W                              NaN    NaN  16.200000
# Ford F108                                   NaN    NaN  15.000000
# Ford F250                                   NaN    NaN  14.000000
# Ford Fairmont                               NaN    NaN  18.100000
# Ford Fairmont (auto)                        NaN    NaN  15.800000
# Ford Fairmont (man)                         NaN    NaN  15.400000
# Ford Fairmont 4                             NaN    NaN  17.300000
# Ford Fairmont Futura                        NaN    NaN  16.400000
# Ford Fiesta                                 NaN    NaN  14.400000
# Ford Futura                                 NaN    NaN  11.200000
# Ford Galaxie 500                            NaN    NaN  12.166667
# Ford Gran Torino                            NaN    NaN  13.766667
# Ford Gran Torino (sw)                       NaN    NaN  16.000000
# Ford Grenada                                NaN    NaN  19.000000
# Ford Grenada ghia                           NaN    NaN  21.000000
# Ford Grenada gl                             NaN    NaN  17.100000
# Ford Grenada l                              NaN    NaN  14.700000
# Ford LTD                                    NaN    NaN  13.250000
# Ford LTD Landau                             NaN    NaN  13.400000
# Ford Maverick                               NaN    NaN  17.320000
# Ford Mustang                                NaN    NaN  14.500000
# Ford Mustang Boss 302                       NaN    NaN   8.000000
# Ford Mustang Cobra                          NaN    NaN  14.300000
# Ford Mustang GL                             NaN    NaN  15.600000
# Ford Mustang II                             NaN    NaN  12.000000
# Ford Mustang II 2+2                         NaN    NaN  15.800000
# Ford Pinto                                  NaN    NaN  16.516667
# Ford Pinto (sw)                             NaN    NaN  16.000000
# Ford Pinto Runabout                         NaN    NaN  16.500000
# Ford Ranger                                 NaN    NaN  18.600000
# Ford Thunderbird                            NaN    NaN  14.500000
# Ford Torino                                 NaN    NaN  10.500000
# Ford Torino (sw)                            NaN    NaN  11.000000
# Ford Torino 500                             NaN    NaN  15.500000
# Hi 1200D                                    NaN    NaN  18.500000
# Honda Accord                                NaN  15.75        NaN
# Honda Accord CVCC                           NaN  18.50        NaN
# Honda Accord LX                             NaN  16.60        NaN
# Honda Civic                                 NaN  15.80        NaN
# Honda Civic (auto)                          NaN  15.70        NaN
# Honda Civic 1300                            NaN  16.10        NaN
# Honda Civic 1500 gl                         NaN  13.80        NaN
# Honda Civic CVCC                            NaN  16.95        NaN
# Honda Prelude                               NaN  14.40        NaN
# Mazda 626                                   NaN  17.90        NaN
# Mazda GLC                                   NaN  17.90        NaN
# Mazda GLC 4                                 NaN  16.00        NaN
# Mazda GLC Custom                            NaN  17.60        NaN
# Mazda GLC Custom l                          NaN  18.20        NaN
# Mazda GLC Deluxe                            NaN  17.30        NaN
# Mazda RX-4                                  NaN  13.50        NaN
# Mazda RX-7 GS                               NaN  12.50        NaN
# Mazda RX2 Coupe                             NaN  13.50        NaN
# Mazda RX3                                   NaN  13.50        NaN
# Mercedes Benz 300d                    20.100000    NaN        NaN
# Mercedes-Benz 240d                    21.800000    NaN        NaN
# Mercedes-Benz 280s                    16.700000    NaN        NaN
# Mercury Capri 2000                          NaN    NaN  14.000000
# Mercury Capri v6                            NaN    NaN  14.000000
# Mercury Cougar Brougham                     NaN    NaN  14.900000
# Mercury Grand Marquis                       NaN    NaN  13.200000
# Mercury Lynx l                              NaN    NaN  17.300000
# Mercury Marquis                             NaN    NaN  11.000000
# Mercury Marquis Brougham                    NaN    NaN  11.500000
# Mercury Monarch                             NaN    NaN  21.000000
# Mercury Monarch ghia                        NaN    NaN  12.800000
# Mercury Zephyr                              NaN    NaN  16.700000
# Mercury Zephyr 6                            NaN    NaN  18.200000
# Nissan Stanza XE                            NaN  14.50        NaN
# Oldsmobile Cutlass Ciera (diesel)           NaN    NaN  17.000000
# Oldsmobile Cutlass LS                       NaN    NaN  19.000000
# Oldsmobile Cutlass Salon Brougham           NaN    NaN  18.850000
# Oldsmobile Cutlass Supreme                  NaN    NaN  19.000000
# Oldsmobile Delta 88 Royale                  NaN    NaN  13.500000
# Oldsmobile Omega                            NaN    NaN  11.000000
# Oldsmobile Omega Brougham                   NaN    NaN  12.900000
# Oldsmobile Starfire SX                      NaN    NaN  17.600000
# Oldsmobile Vista Cruiser                    NaN    NaN  12.500000
# Opel 1900                             15.450000    NaN        NaN
# Opel Manta                            15.000000    NaN        NaN
# Peugeot 304                           19.500000    NaN        NaN
# Peugeot 504                           20.300000    NaN        NaN
# Peugeot 504 (sw)                      19.500000    NaN        NaN
# Peugeot 505s Turbo Diesel             20.400000    NaN        NaN
# Peugeot 604sl                         15.800000    NaN        NaN
# Plymouth 'Cuda 340                          NaN    NaN   8.000000
# Plymouth Arrow GS                           NaN    NaN  15.500000
# Plymouth Champ                              NaN    NaN  16.400000
# Plymouth Cricket                            NaN    NaN  20.500000
# Plymouth Custom Suburb                      NaN    NaN  13.000000
# Plymouth Duster                             NaN    NaN  16.000000
# Plymouth Fury                               NaN    NaN  19.000000
# Plymouth Fury Gran Sedan                    NaN    NaN  14.500000
# Plymouth Fury III                           NaN    NaN  13.500000
# Plymouth Fury iii                           NaN    NaN  10.750000
# Plymouth Grand Fury                         NaN    NaN  14.500000
# Plymouth Horizon                            NaN    NaN  13.200000
# Plymouth Horizon 4                          NaN    NaN  14.900000
# Plymouth Horizon Miser                      NaN    NaN  14.700000
# Plymouth Horizon TC3                        NaN    NaN  14.900000
# Plymouth Reliant                            NaN    NaN  14.300000
# Plymouth Sapporo                            NaN    NaN  16.700000
# Plymouth Satellite                          NaN    NaN  11.000000
# Plymouth Satellite (sw)                     NaN    NaN  10.500000
# Plymouth Satellite Custom                   NaN    NaN  15.500000
# Plymouth Satellite Custom (sw)              NaN    NaN  14.000000
# Plymouth Satellite Sebring                  NaN    NaN  16.500000
# Plymouth Valiant                            NaN    NaN  15.950000
# Plymouth Valiant Custom                     NaN    NaN  16.000000
# Plymouth Volare                             NaN    NaN  17.200000
# Plymouth Volare Custom                      NaN    NaN  17.700000
# Plymouth Volare Premier v8                  NaN    NaN  13.200000
# Pontiac Astro                               NaN    NaN  18.500000
# Pontiac Catalina                            NaN    NaN  11.166667
# Pontiac Catalina Brougham                   NaN    NaN  11.500000
# Pontiac Firebird                            NaN    NaN  15.000000
# Pontiac Grand Prix                          NaN    NaN   9.500000
# Pontiac Grand Prix LJ                       NaN    NaN  11.100000
# Pontiac J2000 SE Hatchback                  NaN    NaN  16.200000
# Pontiac Lemans V6                           NaN    NaN  15.400000
# Pontiac Phoenix                             NaN    NaN  15.600000
# Pontiac Phoenix LJ                          NaN    NaN  19.200000
# Pontiac Safari (sw)                         NaN    NaN  12.000000
# Pontiac Sunbird Coupe                       NaN    NaN  16.000000
# Pontiac Ventura SJ                          NaN    NaN  16.200000
# Renault 12 (sw)                       18.000000    NaN        NaN
# Renault 12tl                          15.300000    NaN        NaN
# Renault 18i                           15.800000    NaN        NaN
# Renault 5 GTL                         18.600000    NaN        NaN
# Renault Lecar Deluxe                  17.300000    NaN        NaN
# Saab 900s                             15.400000    NaN        NaN
# Saab 99LE                             13.500000    NaN        NaN
# Saab 99e                              17.500000    NaN        NaN
# Saab 99gle                            15.700000    NaN        NaN
# Saab 99le                             14.000000    NaN        NaN
# Subaru                                      NaN  16.65        NaN
# Subaru DL                                   NaN  17.20        NaN
# Toyota Camry                                NaN  19.00        NaN
# Toyota Celica GT                            NaN  13.90        NaN
# Toyota Celica GT Liftback                   NaN  14.80        NaN
# Toyota Corolla                              NaN  15.50        NaN
# Toyota Corolla 1200                         NaN  20.00        NaN
# Toyota Corolla 1600 (sw)                    NaN  16.50        NaN
# Toyota Corolla Hardtop                      NaN  15.50        NaN
# Toyota Corolla Liftback                     NaN  16.85        NaN
# Toyota Corolla Mark II (sw)                 NaN  14.50        NaN
# Toyota Corolla Mark ii                      NaN  15.00        NaN
# Toyota Corolla Tercel                       NaN  18.80        NaN
# Toyota Cressida                             NaN  12.60        NaN
# Toyota Mark II                              NaN  14.50        NaN
# Toyota Starlet                              NaN  16.90        NaN
# Toyota Tercel                               NaN  17.30        NaN
# Triumph TR7 Coupe                     15.100000    NaN        NaN
# Volkswagen 1131 Deluxe Sedan          20.500000    NaN        NaN
# Volkswagen 411 (sw)                   18.000000    NaN        NaN
# Volkswagen Dasher                     15.366667    NaN        NaN
# Volkswagen Dasher (diesel)            23.700000    NaN        NaN
# Volkswagen Jetta                      14.200000    NaN        NaN
# Volkswagen Model 111                  19.000000    NaN        NaN
# Volkswagen Pickup                     24.600000    NaN        NaN
# Volkswagen Rabbit                     14.080000    NaN        NaN
# Volkswagen Rabbit C (Diesel)          21.700000    NaN        NaN
# Volkswagen Rabbit Custom              14.250000    NaN        NaN
# Volkswagen Rabbit Custom Diesel       21.500000    NaN        NaN
# Volkswagen Rabbit l                   15.300000    NaN        NaN
# Volkswagen Scirocco                   14.900000    NaN        NaN
# Volkswagen Super Beetle               21.000000    NaN        NaN
# Volkswagen Super Beetle 117           20.000000    NaN        NaN
# Volkswagen Type 3                     23.500000    NaN        NaN
# Volvo 144ea                           15.500000    NaN        NaN
# Volvo 145e (sw)                       14.500000    NaN        NaN
# Volvo 244DL                           14.500000    NaN        NaN
# Volvo 245                             15.700000    NaN        NaN
# Volvo 264gl                           13.600000    NaN        NaN
# Volvo Diesel                          19.600000    NaN        NaN

# %% [markdown]
# **Creating Dataframe from json docs**

# %%
df_cars1 = pd.DataFrame({'name': ['bmw', 'lexus', 'ferrari', 'mercedez'],
                                'colour': ['red', 'white', 'black', 'blue'],
                                'year': ['2012', '2014', '2011', '2016'],
                               },index=[0, 1, 2,3])
df_cars2 = pd.DataFrame({'name': ['audi', 'hyundai', 'maruti', 'ford'],
                                'colour': ['grey', 'brown', 'yellow', 'white'],
                                'year': ['2011', '2014', '2012', '2015'],
                               },index=[4,5,6,7])
df_car_details = pd.DataFrame({'country': ['germany', 'france', 'US', 'UK'],
                                'units': ['2500', '4700', '3250', '6470'],
                                'variant': ['diesel', 'petrol', 'petrol', 'diesel'],
                               },index=[0, 1,2,3])

# %%
df_cars1
# Out:
#        name colour  year
# 0       bmw    red  2012
# 1     lexus  white  2014
# 2   ferrari  black  2011
# 3  mercedez   blue  2016

# %%
df_cars2
# Out:
#       name  colour  year
# 4     audi    grey  2011
# 5  hyundai   brown  2014
# 6   maruti  yellow  2012
# 7     ford   white  2015

# %%
df_car_details
# Out:
#    country units variant
# 0  germany  2500  diesel
# 1   france  4700  petrol
# 2       US  3250  petrol
# 3       UK  6470  diesel

# %% [markdown]
# **Concat , Merge & Join operations**

# %%
#axis 0 = row wise
pd.concat([df_cars1,df_cars2],axis=0)
# Out:
#        name  colour  year
# 0       bmw     red  2012
# 1     lexus   white  2014
# 2   ferrari   black  2011
# 3  mercedez    blue  2016
# 4      audi    grey  2011
# 5   hyundai   brown  2014
# 6    maruti  yellow  2012
# 7      ford   white  2015

# %%
#axis 1 = column wise
pd.concat([df_cars1,df_cars2],axis=1)
# Out:
#        name colour  year     name  colour  year
# 0       bmw    red  2012      NaN     NaN   NaN
# 1     lexus  white  2014      NaN     NaN   NaN
# 2   ferrari  black  2011      NaN     NaN   NaN
# 3  mercedez   blue  2016      NaN     NaN   NaN
# 4       NaN    NaN   NaN     audi    grey  2011
# 5       NaN    NaN   NaN  hyundai   brown  2014
# 6       NaN    NaN   NaN   maruti  yellow  2012
# 7       NaN    NaN   NaN     ford   white  2015

# %% [markdown]
# Merge Operation

# %%
#Merges on the joining column ID ,creates different column names
pd.merge(df_cars1,df_cars2,how='outer',left_on='year',right_on='year')
# Out:
#      name_x colour_x  year   name_y colour_y
# 0       bmw      red  2012   maruti   yellow
# 1     lexus    white  2014  hyundai    brown
# 2   ferrari    black  2011     audi     grey
# 3  mercedez     blue  2016      NaN      NaN
# 4       NaN      NaN  2015     ford    white

# %% [markdown]
# Join operation

# %%
#Joining Dataframe cars 2 to dataframe cars 1
pd.DataFrame.join(df_cars1,df_cars2,lsuffix='_left',rsuffix='_right')
# Out:
#   name_left colour_left year_left name_right colour_right year_right
# 0       bmw         red      2012        NaN          NaN        NaN
# 1     lexus       white      2014        NaN          NaN        NaN
# 2   ferrari       black      2011        NaN          NaN        NaN
# 3  mercedez        blue      2016        NaN          NaN        NaN

# %%
#Joining Dataframe cars 1 to dataframe cars 2
pd.DataFrame.join(df_cars2,df_cars1,lsuffix='_left',rsuffix='_right')
# Out:
#   name_left colour_left year_left name_right colour_right year_right
# 4      audi        grey      2011        NaN          NaN        NaN
# 5   hyundai       brown      2014        NaN          NaN        NaN
# 6    maruti      yellow      2012        NaN          NaN        NaN
# 7      ford       white      2015        NaN          NaN        NaN

# %%
 # Joining dataframe car details to cars1 ,having same indexes
pd.DataFrame.join(df_cars1,df_car_details)
# Out:
#        name colour  year  country units variant
# 0       bmw    red  2012  germany  2500  diesel
# 1     lexus  white  2014   france  4700  petrol
# 2   ferrari  black  2011       US  3250  petrol
# 3  mercedez   blue  2016       UK  6470  diesel

# %% [markdown]
# ## **Data Analysis**

# %% [markdown]
# **Problem 1** :Given that First word in the all the 'Car' field represents the company manufacturing the car and rest of the words represent the car model , Find out the different companies with their origins and the total number of models produced by them

# %%
df_csv[['Company','Model']] = df_csv.Car.str.split(" ",1,expand=True)

# %%
df_csv.head(10)
# Out:
#                          Car   MPG  Cylinders  ...  Origin  NetHPWt    Company
# 0  Chevrolet Chevelle Malibu  18.0          8  ...      US   3634.0  Chevrolet
# 1          Buick Skylark 320  15.0          8  ...      US   3858.0      Buick
# 2         Plymouth Satellite  18.0          8  ...      US   3586.0   Plymouth
# 3              AMC Rebel SST  16.0          8  ...      US   3583.0        AMC
# 4                Ford Torino  17.0          8  ...      US   3589.0       Ford
# 5           Ford Galaxie 500  15.0          8  ...      US   4539.0       Ford
# 6           Chevrolet Impala  14.0          8  ...      US   4574.0  Chevrolet
# 7          Plymouth Fury iii  14.0          8  ...      US   4527.0   Plymouth
# 8           Pontiac Catalina  14.0          8  ...      US   4650.0    Pontiac
# 9         AMC Ambassador DPL  15.0          8  ...      US   4040.0        AMC
#
# [10 rows x 11 columns]

# %%
df_csv.groupby(['Company','Origin'])['Model'].count()
# Out:
# Company        Origin
# AMC            US        29
# Audi           Europe     7
# BMW            Europe     2
# Buick          US        17
# Cadillac       US         2
# Capri          US         1
# Chevrolet      US        45
# Chevrolete     US         1
# Chevy          US         2
# Chrysler       US         6
# Citroen        Europe     1
# Datsun         Japan     23
# Dodge          US        28
# Fiat           Europe     8
# Ford           US        53
# Hi             US         1
# Honda          Japan     13
# Mazda          Japan     12
# Mercedes       Europe     1
# Mercedes-Benz  Europe     2
# Mercury        US        11
# Nissan         Japan      1
# Oldsmobile     US        10
# Opel           Europe     4
# Peugeot        Europe     8
# Plymouth       US        32
# Pontiac        US        16
# Renault        Europe     5
# Saab           Europe     5
# Subaru         Japan      2
# Toyota         Japan     26
# Triumph        Europe     1
# Volkswagen     Europe    23
# Volvo          Europe     6
# Name: Model, dtype: int64

# %% [markdown]
# **Problem 2**: Find out all the companies of US & Japan that produce cars with Horse power > 100

# %%
#To show all records
pd.set_option('display.max_rows', df_csv.shape[0]+1)

# %%
df_csv.loc[(df_csv['Origin'].isin(['US','Japan'])) & (df_csv['Horsepower'] > 100)][['Company','Origin','Horsepower']]
# Out:
#         Company Origin  Horsepower
# 0     Chevrolet     US       130.0
# 1         Buick     US       165.0
# 2      Plymouth     US       150.0
# 3           AMC     US       150.0
# 4          Ford     US       140.0
# 5          Ford     US       198.0
# 6     Chevrolet     US       220.0
# 7      Plymouth     US       215.0
# 8       Pontiac     US       225.0
# 9           AMC     US       190.0
# 11    Chevrolet     US       165.0
# 12         Ford     US       153.0
# 13     Plymouth     US       175.0
# 14          AMC     US       175.0
# 15        Dodge     US       170.0
# 16     Plymouth     US       160.0
# 17         Ford     US       140.0
# 18    Chevrolet     US       150.0
# 19        Buick     US       225.0
# 31         Ford     US       215.0
# 32        Chevy     US       200.0
# 33        Dodge     US       210.0
# 34           Hi     US       193.0
# 41     Plymouth     US       105.0
# 45    Chevrolet     US       165.0
# 46      Pontiac     US       175.0
# 47         Ford     US       153.0
# 48     Plymouth     US       150.0
# 49        Dodge     US       180.0
# 50         Ford     US       170.0
# 51      Pontiac     US       175.0
# 52          AMC     US       110.0
# 69    Chevrolet     US       165.0
# 70      Pontiac     US       175.0
# 71     Plymouth     US       150.0
# 72         Ford     US       153.0
# 73          AMC     US       150.0
# 74      Mercury     US       208.0
# 75        Buick     US       155.0
# 76   Oldsmobile     US       160.0
# 77     Chrysler     US       190.0
# 79          AMC     US       150.0
# 80    Chevrolet     US       130.0
# 81         Ford     US       140.0
# 82     Plymouth     US       150.0
# 92        Buick     US       175.0
# 93          AMC     US       150.0
# 94    Chevrolet     US       145.0
# 95         Ford     US       137.0
# 96        Dodge     US       150.0
# 97      Mercury     US       198.0
# 98    Chevrolet     US       150.0
# 99         Ford     US       158.0
# 100    Plymouth     US       150.0
# 101    Chrysler     US       215.0
# 102       Buick     US       225.0
# 103         AMC     US       175.0
# 104    Plymouth     US       105.0
# 110   Chevrolet     US       150.0
# 111        Ford     US       167.0
# 112    Plymouth     US       170.0
# 113  Oldsmobile     US       180.0
# 120     Mercury     US       107.0
# 122   Chevrolet     US       145.0
# 123     Pontiac     US       230.0
# 128       Dodge     US       150.0
# 130      Toyota  Japan       122.0
# 131  Oldsmobile     US       180.0
# 141         AMC     US       110.0
# 142    Plymouth     US       105.0
# 143        Ford     US       140.0
# 144       Buick     US       150.0
# 145       Dodge     US       150.0
# 146        Ford     US       140.0
# 147         AMC     US       150.0
# 160   Chevrolet     US       105.0
# 163     Pontiac     US       170.0
# 164   Chevrolet     US       145.0
# 165    Plymouth     US       150.0
# 166        Ford     US       148.0
# 167       Buick     US       110.0
# 168  Chevrolete     US       105.0
# 169         AMC     US       110.0
# 171       Buick     US       110.0
# 172   Chevrolet     US       110.0
# 173        Ford     US       129.0
# 194   Chevrolet     US       140.0
# 195       Dodge     US       150.0
# 196         AMC     US       120.0
# 197        Ford     US       152.0
# 199   Chevrolet     US       105.0
# 208     Pontiac     US       110.0
# 215    Plymouth     US       150.0
# 217      Toyota  Japan       108.0
# 219    Cadillac     US       180.0
# 220   Chevrolet     US       145.0
# 221        Ford     US       130.0
# 222       Dodge     US       150.0
# 228   Chevrolet     US       145.0
# 229  Oldsmobile     US       110.0
# 230       Dodge     US       145.0
# 231     Mercury     US       130.0
# 232   Chevrolet     US       110.0
# 233       Buick     US       105.0
# 236     Pontiac     US       180.0
# 237   Chevrolet     US       170.0
# 238    Chrysler     US       190.0
# 239        Ford     US       149.0
# 250       Mazda  Japan       110.0
# 256  Oldsmobile     US       110.0
# 257       Dodge     US       140.0
# 258     Mercury     US       139.0
# 259     Pontiac     US       105.0
# 265       Buick     US       105.0
# 267       Dodge     US       110.0
# 268         AMC     US       120.0
# 269   Chevrolet     US       145.0
# 270       Buick     US       165.0
# 271        Ford     US       139.0
# 272       Dodge     US       140.0
# 278    Plymouth     US       105.0
# 287     Pontiac     US       115.0
# 291       Dodge     US       110.0
# 292   Chevrolet     US       130.0
# 293        Ford     US       129.0
# 294     Mercury     US       138.0
# 295       Dodge     US       135.0
# 296       Buick     US       155.0
# 297        Ford     US       142.0
# 298   Chevrolet     US       125.0
# 299    Chrysler     US       150.0
# 305    Cadillac     US       125.0
# 313   Chevrolet     US       115.0
# 314  Oldsmobile     US       115.0
# 330       Dodge     US       105.0
# 340      Datsun  Japan       132.0
# 348   Chevrolet     US       110.0
# 369      Toyota  Japan       116.0
# 370      Datsun  Japan       120.0
# 371       Buick     US       110.0
# 372  Oldsmobile     US       105.0
# 394       Buick     US       110.0
# 397        Ford     US       112.0

# %% [markdown]
# **Problem 3** : Which is the most Light weight car in Europe ?

# %%
df_csv [(df_csv['Weight'] == df_csv[(df_csv['Origin'] == 'Europe')]['Weight'].min())][['Car','Origin','Weight']]
# Out:
#                    Car  Origin  Weight
# 210  Volkswagen Rabbit  Europe  1825.0
# 225      Renault 5 GTL  Europe  1825.0
